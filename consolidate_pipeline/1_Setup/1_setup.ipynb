# %%
# %sql

create catalog if not exists fmcg;
use catalog fmcg;

# %%
# %sql
create schema if not exists fmcg_gold;
create schema if not exists fmcg_silver;
create schema if not exists fmcg_bronze;
